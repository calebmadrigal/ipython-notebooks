# %%
x = numpy.arange(0,2 * pi, 0.1)
f1 = [5*sin(i) for i in x]
f2 = [2*sin(2*i) for i in x]
f3 = [1*sin(3*i) for i in x]
pylab.plot(x, f1)
pylab.plot(x, f2, 'ro')
pylab.plot(x, f3, 'g--')
pylab.show()
